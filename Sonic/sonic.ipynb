# %% [markdown]
# attribution : https://www.kaggle.com/wfaria/midi-music-data-extraction-using-music21

# %%
from music21 import converter, corpus, instrument, midi, note, chord, pitch
import pandas as pd
import numpy as np
import os

# %%
mf_parser = midi.MidiFile ()

# %%
mf.open('midi_sonic/emerald-hill-zone.mid')
mf.read()
mf.close()

# %%
sonic = midi.translate.midiFileToStream(mf)

# %%
def list_instruments(midi):
    partStream = midi.parts.stream()
    print("List of instruments found on MIDI file:")
    for p in partStream:
        aux = p
        print (p.partName)

list_instruments(sonic)
# Out:
# List of instruments found on MIDI file:
# None
# None
# Saxophone
# None
# Vibraphone
# None
# Guitar
# None
# None
# Saxophone
# None
# Vibraphone
# None
# Guitar
# None
# None
# Saxophone
# None
# Vibraphone
# None
# Guitar

# %%
# sonic.plot('scatter', 'offset', 'pitchClass')

# %%
dir (sonic)
# Out:
# ['_DOC_ATTR',
#  '_DOC_ORDER',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accumulatedSeconds',
#  '_activeSite',
#  '_activeSiteStoredOffset',
#  '_atSoundingPitch',
#  '_cache',
#  '_classListFullyQualifiedCacheDict',
#  '_classSetCacheDict',
#  '_classTupleCacheDict',
#  '_consolidateLayering',
#  '_deepcopySubclassable',
#  '_derivation',
#  '_durSpanOverlap',
#  '_duration',
#  '_editorial',
#  '_elements',
#  '_endElements',
# ...

# %%
for i in range (len(sonic.parts[0])):
    print (sonic.parts[0][i])
# Out:
# <music21.tempo.MetronomeMark allegrissimo Quarter=140.0>
# <music21.tempo.MetronomeMark allegrissimo Quarter=140.0>
# <music21.tempo.MetronomeMark allegrissimo Quarter=140.0>
# D major
# D major
# D major
# <music21.meter.TimeSignature 4/4>
# <music21.meter.TimeSignature 4/4>
# <music21.meter.TimeSignature 4/4>
# <music21.chord.Chord A4 E5>
# <music21.chord.Chord B4 F#5>
# <music21.note.Rest rest>
# <music21.chord.Chord G#4 E-5>
# <music21.note.Rest rest>
# <music21.chord.Chord A4 E5>
# <music21.note.Rest rest>
# <music21.chord.Chord B-4 F5>
# <music21.note.Rest rest>
# B major
# B major
# B major
# <music21.note.Note F#>
# <music21.note.Note G#>
# <music21.note.Note F#>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.note.Note C#>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Rest rest>
# <music21.note.Note C#>
# ...

# %% [markdown]
# _note:_ Concerned that MIDI files would have too much parsed data, instead of single notes / instruments.

# %%
sonic[0].analyze('key')
# Out:
# <music21.key.Key of g# minor>
