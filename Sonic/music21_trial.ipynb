# %%
from music21 import stream, converter, corpus, instrument, midi, note, chord, pitch
import pandas as pd
import numpy as np
import os

# %%
mf = midi.MidiFile ()
mf.open('midi_sonic/gutsman.mid')
mf.read()
mf.close()

# %%
type (mf)
# Out:
# music21.midi.MidiFile

# %%
s = midi.translate.midiFileToStream(mf)
type (s)
# Out:
# music21.stream.Score

# %% [markdown]
# ### Trial For Possible Reconstruction
#
# __Midi > Stream > Data > Training > NN Production > Data > Stream > Midi__

# %%
note1 = note.Note('F')
note2 = note.Note('C')
note3 = note.Note('B-2')
note4 = note.Note('C-2')
note5 = note.Note('E')
chord1 = chord.Chord('E5 E4 E4 E5 E5 E2 E2 E2 F2')
pitch1 = pitch.Pitch('C4')
note6 = note.Note('F')
note7 = note.Note('C')
note8 = note.Note('B-2')
note9 = note.Note('C-2')

# %%
noteList = [note1, note2, note3, note4, note5, chord1, note6, note7, note8, note9]

# %%
stream1 = stream.Stream()

# %%
stream1.append (noteList)

# %%
stream1.show('midi')
# Out:
#                 <div id='midiPlayerDiv79064'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv79064');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %% [markdown]
# _It works!_
#
# Next Question, Can I change the instrument?
# Answer, Doesn't seem like it.

# %%
s_flat = s.flat

# %%
s_flat.show('midi') # <- plays all chords and note concurrent
# Out:
#                 <div id='midiPlayerDiv90188'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv90188');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
s.show('midi') # <- plays only piano portion
# Out:
#                 <div id='midiPlayerDiv101320'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv101320');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
s_flat_elem = s_flat.getElementsByOffset(0.0)

# %%
len(s_flat_elem)
# Out:
# 17

# %%
s_flat_elem.next
# Out:
# <bound method Music21Object.next of <music21.stream.Score 0x19bd5c49438_flat>>

# %%
s_flat_elem.elements
# Out:
# (<music21.instrument.Instrument ''>,
#  <music21.instrument.Instrument ''>,
#  <music21.instrument.AcousticBass 'Acoustic Bass'>,
#  <music21.instrument.Piano 'Piano'>,
#  <music21.tempo.MetronomeMark Quarter=150.0>,
#  <music21.key.Key of C major>,
#  <music21.key.Key of C major>,
#  <music21.key.Key of C major>,
#  <music21.key.Key of C major>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.meter.TimeSignature 4/4>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note G#>)

# %%
s.elements
# Out:
# (<music21.stream.Part 0x19bd5c4e160>,
#  <music21.stream.Part 0x19bd5d49be0>,
#  <music21.stream.Part 0x19bd5b19a90>,
#  <music21.stream.Part 0x19bd41bec18>)

# %%
s_class = s.getElementsByClass

# %%
s_flat_class = s_flat.getElementsByClass

# %%
dir(s_class)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
# Out:
# '<bound method Stream.getElementsByClass of <music21.stream.Score 0x19bd5c49438>>'
